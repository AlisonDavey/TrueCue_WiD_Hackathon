# %% [markdown]
# <a href="https://colab.research.google.com/gist/annauk/40f4be4a8e41c2b2a2157496981f792f/covidcorr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import numpy as np
uploaded = files.upload()
dcovid = pd.read_csv("COVID19 Hackathon Dataset.csv")
# Out:
#      <input type="file" id="files-ec7ae6ae-97f2-49b9-b2cd-18db39350646" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec7ae6ae-97f2-49b9-b2cd-18db39350646">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving COVID19 Hackathon Dataset.csv to COVID19 Hackathon Dataset (1).csv

# %%
dcovid.fillna(0, inplace=True)
df=dcovid.drop(columns=['Countries']) 
df
# Out:
#              Date Continent  ...  Hospital Beds Year  Hospital Beds Per 1000 People
# 0      2019-12-31      Asia  ...              2015.0                            0.5
# 1      2020-01-01      Asia  ...              2015.0                            0.5
# 2      2020-01-02      Asia  ...              2015.0                            0.5
# 3      2020-01-03      Asia  ...              2015.0                            0.5
# 4      2020-01-04      Asia  ...              2015.0                            0.5
# ...           ...       ...  ...                 ...                            ...
# 41777  2020-10-03    Africa  ...              2011.0                            1.7
# 41778  2020-10-04    Africa  ...              2011.0                            1.7
# 41779  2020-10-05    Africa  ...              2011.0                            1.7
# 41780  2020-10-06    Africa  ...              2011.0                            1.7
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(40,40))
sns.heatmap(df.corr(),annot = True)

# %%
correlation_mat = df.corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# New_Cases                      New_Cases                                                                                              1.000000
#                                New_Deaths                                                                                             0.735109
#                                Total_Cases                                                                                            0.847127
#                                Total_Deaths                                                                                           0.752957
#                                Weekly_Cases                                                                                           0.982296
#                                                                                                                                         ...
# ...

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# Fertility_Rate                                                                 Government_Effectiveness                                                        -0.636425
# Government_Effectiveness                                                       Fertility_Rate                                                                  -0.636425
# Political_Stability                                                            Fertility_Rate                                                                  -0.604105
# Fertility_Rate                                                                 Political_Stability                                                             -0.604105
#                                                                                Rule_of_Law                                                                     -0.582877
# ...

# %%
negative_pairs = sorted_pairs[sorted_pairs < 0]

print(negative_pairs)
# Out:
# Fertility_Rate                                                                                       Government_Effectiveness                                                                              -0.636425
# Government_Effectiveness                                                                             Fertility_Rate                                                                                        -0.636425
# Political_Stability                                                                                  Fertility_Rate                                                                                        -0.604105
# Fertility_Rate                                                                                       Political_Stability                                                                                   -0.604105
# ...

# %%
postive_pairs = sorted_pairs[sorted_pairs > 0.5] 

postive_pairs
# Out:
# Hospital Beds Year                                                                                   PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)    0.510326
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)  Hospital Beds Year                                                                                     0.510326
#                                                                                                      Year                                                                                                   0.510968
# Year                                                                                                 PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)    0.510968
# ...

# %%
from google.colab import files
postive_pairs.to_csv('covid.csv') 
files.download('covid.csv')
